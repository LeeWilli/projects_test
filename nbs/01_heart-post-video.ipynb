# %% [markdown]
# # Notebook Test for Project
#
# > A test for bpm, spo2 and respirat.

# %%
# | default_exp core

# %%
# | export
# the sample is from http://git.xinktech.com/yscz/alg/hr_detect_server/uploads/81dac5cbf6904113c61dee9305e9eada/sample.mp4
video_path = video_DIR = '/home/wangli/data/pulse_rate/aliyun/2023.7.26/15.mp4'
server_ip = "localhost:8293"  # ip and port of the server.
hr_server_url = "http://{}/".format(server_ip)  # url of the server.

# %%
import requests

url = "http://localhost:8293/process_video"

# 上传的文件和参数
files = {'video': open(video_path, 'rb')}
data = {'camera_fps': 25, 'best': True, 'save_video': False}

# 发送POST请求
response = requests.post(url, files=files, data=data)

#assert response.json()['bpm'][1] > 0 # the snr of sample.mp4 should be larger than 0
#assert response.json()['rpm'] is None # the rpm of sample.mp4 should be None for the time is less than 16s
#assert response.json()['spo2'][0] > 90 # the spo2 of sample.mp4 should be larger than 90

# 打印响应
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/anaconda3/envs/nbdev/lib/python3.9/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# ...

# %%
print(response.text)
# Out:
# {"bpm":[73.24,0.4],"rpm":[20.51,-4.19],"spo2":[94.89,0],"sbp":[1,0.0],"dbp":[0,0.0]}

# %%
print(response.text)
# Out:
# {"bpm":[73.24,0.4],"rpm":[20.51,-4.19],"spo2":[94.89,0],"sbp":[1,0.0],"dbp":[0,0.0]}
